# %% [markdown]
# <a href="https://colab.research.google.com/github/yakupilyas/GoogleColabIntro/blob/main/Ders5_raw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Matlab kütüphanemizi colab a tanıttık import ettik 🠗🠗🠗**

# %%
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = 5, 10
from matplotlib.pyplot import imshow

# %% [markdown]
# **rawpy formatında kütüphanemizi ekledik 🠗🠗🠗**

# %%
pip install rawpy
# Out:
# ...
#      |████████████████████████████████| 1.7MB 11.0MB/s
# ...

# %% [markdown]
# **import etme işlemini gerçekleştirdik. 🠗🠗🠗**

# %%
import rawpy
import PIL

import numpy as np

# %% [markdown]
# **colaba yüklediğimiz fotoğrafımızı kodumuza okuttuk. 🠗🠗🠗**

# %%
raw = rawpy.imread('RAW_NIKON_D3X.NEF')

# %% [markdown]
# **fotoğrafımızı rgb olarak ayarladık ve boyutlarını print ettik.**

# %%
rgb = raw.postprocess(use_camera_wb=True)

# %%
print(rgb.dtype, rgb.shape)
# Out:
# uint8 (6080, 4044, 3)

# %% [markdown]
# **imshow komutu ile resmimizi ekranda gösterdik.🠗🠗🠗**

# %%
imshow(rgb)

# %%
rgb2 = raw.postprocess(use_auto_wb=True)
imshow(rgb2)

# %%
PIL.Image.fromarray(rgb).save('image.jpg', quality=90, optimize=True)

# %%
PIL.Image.fromarray(rgb).save('image.tiff')

# %%
raw.close()
